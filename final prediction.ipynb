# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#         id        date  store_nbr      family  onpromotion
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0
# 1  3000889  2017-08-16          1   BABY CARE            0
# 2  3000890  2017-08-16          1      BEAUTY            2
# 3  3000891  2017-08-16          1   BEVERAGES           20
# 4  3000892  2017-08-16          1       BOOKS            0

# %%
df_test = test.merge(stores , how = 'left', on = 'store_nbr')
df_test.head()
# Out:
#         id        date  store_nbr      family  onpromotion   city      state  \
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0  Quito  Pichincha
# 1  3000889  2017-08-16          1   BABY CARE            0  Quito  Pichincha
# 2  3000890  2017-08-16          1      BEAUTY            2  Quito  Pichincha
# 3  3000891  2017-08-16          1   BEVERAGES           20  Quito  Pichincha
# 4  3000892  2017-08-16          1       BOOKS            0  Quito  Pichincha
#
#   type  cluster
# 0    D       13
# 1    D       13
# 2    D       13
# 3    D       13
# 4    D       13

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1  2013-01-01          1   BABY CARE    0.0            0
# 2   2  2013-01-01          1      BEAUTY    0.0            0
# 3   3  2013-01-01          1   BEVERAGES    0.0            0
# 4   4  2013-01-01          1       BOOKS    0.0            0

# %%
stores = pd.read_csv("stores.csv")
stores.head()
# Out:
#    store_nbr           city                           state type  cluster
# 0          1          Quito                       Pichincha    D       13
# 1          2          Quito                       Pichincha    D       13
# 2          3          Quito                       Pichincha    D        8
# 3          4          Quito                       Pichincha    D        9
# 4          5  Santo Domingo  Santo Domingo de los Tsachilas    D        4

# %%
df_train = train.merge(stores , how = 'left', on = 'store_nbr')
df_train.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion   city  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Quito
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Quito
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Quito
# 4   4  2013-01-01          1       BOOKS    0.0            0  Quito
#
#        state type  cluster
# 0  Pichincha    D       13
# 1  Pichincha    D       13
# 2  Pichincha    D       13
# 3  Pichincha    D       13
# 4  Pichincha    D       13

# %%
oil = pd.read_csv("oil.csv")
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %%
df_train_1 = df_train.merge(oil, how = 'left', on = 'date')
df_train_1.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion   city  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Quito
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Quito
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Quito
# 4   4  2013-01-01          1       BOOKS    0.0            0  Quito
#
#        state type  cluster  dcoilwtico
# 0  Pichincha    D       13         NaN
# 1  Pichincha    D       13         NaN
# 2  Pichincha    D       13         NaN
# 3  Pichincha    D       13         NaN
# 4  Pichincha    D       13         NaN

# %%
df_test_1 = df_test.merge(oil, how = 'left', on = 'date')
df_test_1.head()
# Out:
#         id        date  store_nbr      family  onpromotion   city      state  \
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0  Quito  Pichincha
# 1  3000889  2017-08-16          1   BABY CARE            0  Quito  Pichincha
# 2  3000890  2017-08-16          1      BEAUTY            2  Quito  Pichincha
# 3  3000891  2017-08-16          1   BEVERAGES           20  Quito  Pichincha
# 4  3000892  2017-08-16          1       BOOKS            0  Quito  Pichincha
#
#   type  cluster  dcoilwtico
# 0    D       13        46.8
# 1    D       13        46.8
# 2    D       13        46.8
# 3    D       13        46.8
# 4    D       13        46.8

# %%
events = pd.read_csv('holidays_events.csv')
events.head()
# Out:
#          date     type    locale locale_name                    description  \
# 0  2012-03-02  Holiday     Local       Manta             Fundacion de Manta
# 1  2012-04-01  Holiday  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2  2012-04-12  Holiday     Local      Cuenca            Fundacion de Cuenca
# 3  2012-04-14  Holiday     Local    Libertad      Cantonizacion de Libertad
# 4  2012-04-21  Holiday     Local    Riobamba      Cantonizacion de Riobamba
#
#    transferred
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
final_train_df = df_train_1.merge(events, how = 'left', on = 'date')
final_train_df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion   city  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Quito
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Quito
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Quito
# 4   4  2013-01-01          1       BOOKS    0.0            0  Quito
#
#        state type_x  cluster  dcoilwtico   type_y    locale locale_name  \
# 0  Pichincha      D       13         NaN  Holiday  National     Ecuador
# 1  Pichincha      D       13         NaN  Holiday  National     Ecuador
# 2  Pichincha      D       13         NaN  Holiday  National     Ecuador
# 3  Pichincha      D       13         NaN  Holiday  National     Ecuador
# 4  Pichincha      D       13         NaN  Holiday  National     Ecuador
#
#           description transferred
# 0  Primer dia del ano       False
# 1  Primer dia del ano       False
# ...

# %%
final_test_df = df_test_1.merge(events, how = 'left', on = 'date')
final_test_df.head()
# Out:
#         id        date  store_nbr      family  onpromotion   city      state  \
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0  Quito  Pichincha
# 1  3000889  2017-08-16          1   BABY CARE            0  Quito  Pichincha
# 2  3000890  2017-08-16          1      BEAUTY            2  Quito  Pichincha
# 3  3000891  2017-08-16          1   BEVERAGES           20  Quito  Pichincha
# 4  3000892  2017-08-16          1       BOOKS            0  Quito  Pichincha
#
#   type_x  cluster  dcoilwtico type_y locale locale_name description  \
# 0      D       13        46.8    NaN    NaN         NaN         NaN
# 1      D       13        46.8    NaN    NaN         NaN         NaN
# 2      D       13        46.8    NaN    NaN         NaN         NaN
# 3      D       13        46.8    NaN    NaN         NaN         NaN
# 4      D       13        46.8    NaN    NaN         NaN         NaN
#
#   transferred
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
final_train_df.isna().sum()
# Out:
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# city                 0
# state                0
# type_x               0
# cluster              0
# dcoilwtico      955152
# type_y         2551824
# locale         2551824
# locale_name    2551824
# description    2551824
# transferred    2551824
# dtype: int64

# %%
final_test_df.isna().sum()
# Out:
# id                 0
# date               0
# store_nbr          0
# family             0
# onpromotion        0
# city               0
# state              0
# type_x             0
# cluster            0
# dcoilwtico      7128
# type_y         26730
# locale         26730
# locale_name    26730
# description    26730
# transferred    26730
# dtype: int64

# %%
oil_median = final_df["dcoilwtico"].median()

# %%
final_train_df["dcoilwtico"] = final_train_df["dcoilwtico"].fillna(oil_median)

# %%
final_test_df["dcoilwtico"] = final_test_df["dcoilwtico"].fillna(oil_median)

# %%
final_train_df.isna().sum()
# Out:
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# city                 0
# state                0
# type_x               0
# cluster              0
# dcoilwtico           0
# type_y         2551824
# locale         2551824
# locale_name    2551824
# description    2551824
# transferred    2551824
# dtype: int64

# %%
final_test_df.isna().sum()
# Out:
# id                 0
# date               0
# store_nbr          0
# family             0
# onpromotion        0
# city               0
# state              0
# type_x             0
# cluster            0
# dcoilwtico         0
# type_y         26730
# locale         26730
# locale_name    26730
# description    26730
# transferred    26730
# dtype: int64

# %%
final_train_df.drop(["type_y","locale","locale_name","description","transferred"],axis = 1, inplace = True)

# %%
final_test_df.drop(["type_y","locale","locale_name","description","transferred"],axis = 1 , inplace = True)

# %%
final_train_df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion   city  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Quito
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Quito
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Quito
# 4   4  2013-01-01          1       BOOKS    0.0            0  Quito
#
#        state type_x  cluster  dcoilwtico
# 0  Pichincha      D       13       53.43
# 1  Pichincha      D       13       53.43
# 2  Pichincha      D       13       53.43
# 3  Pichincha      D       13       53.43
# 4  Pichincha      D       13       53.43

# %%
final_test_df.head()
# Out:
#         id        date  store_nbr      family  onpromotion   city      state  \
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0  Quito  Pichincha
# 1  3000889  2017-08-16          1   BABY CARE            0  Quito  Pichincha
# 2  3000890  2017-08-16          1      BEAUTY            2  Quito  Pichincha
# 3  3000891  2017-08-16          1   BEVERAGES           20  Quito  Pichincha
# 4  3000892  2017-08-16          1       BOOKS            0  Quito  Pichincha
#
#   type_x  cluster  dcoilwtico
# 0      D       13        46.8
# 1      D       13        46.8
# 2      D       13        46.8
# 3      D       13        46.8
# 4      D       13        46.8

# %%
final_train_df.drop(["city","cluster","dcoilwtico"],axis = 1 , inplace = True)

# %%
final_test_df.drop(["city","cluster","dcoilwtico"],axis = 1 , inplace = True)

# %%
final_train_df.head()
# Out:
#    id        date  store_nbr      family  sales  onpromotion      state type_x
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Pichincha      D
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Pichincha      D
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Pichincha      D
# 3   3  2013-01-01          1   BEVERAGES    0.0            0  Pichincha      D
# 4   4  2013-01-01          1       BOOKS    0.0            0  Pichincha      D

# %%
final_test_df.head()
# Out:
#         id        date  store_nbr      family  onpromotion      state type_x
# 0  3000888  2017-08-16          1  AUTOMOTIVE            0  Pichincha      D
# 1  3000889  2017-08-16          1   BABY CARE            0  Pichincha      D
# 2  3000890  2017-08-16          1      BEAUTY            2  Pichincha      D
# 3  3000891  2017-08-16          1   BEVERAGES           20  Pichincha      D
# 4  3000892  2017-08-16          1       BOOKS            0  Pichincha      D

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
categorical = ["family","state","type_x"]

# %%
label_encoder = LabelEncoder()
for column in categorical:
    final_train_df[column] = label_encoder.fit_transform(final_train_df[column])

# %%
label_encoder = LabelEncoder()
for column in categorical:
    final_test_df[column] = label_encoder.fit_transform(final_test_df[column])

# %%
final_train_df.head()
# Out:
#    id        date  store_nbr  family  sales  onpromotion  state  type_x
# 0   0  2013-01-01          1       0    0.0            0     12       3
# 1   1  2013-01-01          1       1    0.0            0     12       3
# 2   2  2013-01-01          1       2    0.0            0     12       3
# 3   3  2013-01-01          1       3    0.0            0     12       3
# 4   4  2013-01-01          1       4    0.0            0     12       3

# %%
final_test_df.head()
# Out:
#         id        date  store_nbr  family  onpromotion  state  type_x
# 0  3000888  2017-08-16          1       0            0     12       3
# 1  3000889  2017-08-16          1       1            0     12       3
# 2  3000890  2017-08-16          1       2            2     12       3
# 3  3000891  2017-08-16          1       3           20     12       3
# 4  3000892  2017-08-16          1       4            0     12       3

# %%
final_train_df['date'] = pd.to_datetime(final_train_df['date'])

# %%
final_test_df['date'] = pd.to_datetime(final_test_df['date'])

# %%
import datetime as dt
final_train_df['date']=final_train_df['date'].map(dt.datetime.toordinal)

# %%
final_test_df['date'] = final_test_df['date'].map(dt.datetime.toordinal)

# %%
final_test_df
# Out:
#             id      date  store_nbr    family  onpromotion     state   type_x
# 0      3000888 -1.626978  -1.700267 -1.680336    -0.336759  0.769193  0.83205
# 1      3000889 -1.626978  -1.700267 -1.575315    -0.336759  0.769193  0.83205
# 2      3000890 -1.626978  -1.700267 -1.470294    -0.240064  0.769193  0.83205
# 3      3000891 -1.626978  -1.700267 -1.365273     0.630191  0.769193  0.83205
# 4      3000892 -1.626978  -1.700267 -1.260252    -0.336759  0.769193  0.83205
# ...        ...       ...        ...       ...          ...       ...      ...
# 28507  3029395  1.626978  -1.186979  1.260252    -0.288411  0.769193 -0.83205
# 28508  3029396  1.626978  -1.186979  1.365273    -0.336759  0.769193 -0.83205
# 28509  3029397  1.626978  -1.186979  1.470294    -0.288411  0.769193 -0.83205
# 28510  3029398  1.626978  -1.186979  1.575315     0.098369  0.769193 -0.83205
# 28511  3029399  1.626978  -1.186979  1.680336    -0.336759  0.769193 -0.83205
#
# [28512 rows x 7 columns]

# %%
final_train_df.head()
# Out:
#    id    date  store_nbr  family  sales  onpromotion  state  type_x
# 0   0  734869          1       0    0.0            0     12       3
# 1   1  734869          1       1    0.0            0     12       3
# 2   2  734869          1       2    0.0            0     12       3
# 3   3  734869          1       3    0.0            0     12       3
# 4   4  734869          1       4    0.0            0     12       3

# %%
scaler = StandardScaler()

# %%
final_train_df[["date","store_nbr","family","onpromotion","state","type_x"]] =scaler.fit_transform(final_train_df[["date","store_nbr","family","onpromotion","state","type_x"]])

# %%
final_test_df[["date","store_nbr","family","onpromotion","state","type_x"]] = scaler.fit_transform(final_test_df[["date","store_nbr","family","onpromotion","state","type_x"]])

# %%
final_test_df.head()
# Out:
#         id      date  store_nbr    family  onpromotion     state   type_x
# 0  3000888 -1.626978  -1.700267 -1.680336    -0.336759  0.769193  0.83205
# 1  3000889 -1.626978  -1.700267 -1.575315    -0.336759  0.769193  0.83205
# 2  3000890 -1.626978  -1.700267 -1.470294    -0.240064  0.769193  0.83205
# 3  3000891 -1.626978  -1.700267 -1.365273     0.630191  0.769193  0.83205
# 4  3000892 -1.626978  -1.700267 -1.260252    -0.336759  0.769193  0.83205

# %%
final_test_df.head()
# Out:
#         id      date  store_nbr    family  onpromotion     state   type_x
# 0  3000888 -1.626978  -1.700267 -1.680336    -0.336759  0.769193  0.83205
# 1  3000889 -1.626978  -1.700267 -1.575315    -0.336759  0.769193  0.83205
# 2  3000890 -1.626978  -1.700267 -1.470294    -0.240064  0.769193  0.83205
# 3  3000891 -1.626978  -1.700267 -1.365273     0.630191  0.769193  0.83205
# 4  3000892 -1.626978  -1.700267 -1.260252    -0.336759  0.769193  0.83205

# %%
final_test_df.drop(["id"],axis = 1 , inplace = True)

# %%
x = final_train_df.loc[:, ['date', 'store_nbr', 'family','onpromotion','state','type_x']]

# %%
y = final_train_df["sales"]

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state=42)

# %%
Dtr = DecisionTreeRegressor(random_state = 42)
Dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
from sklearn.metrics import mean_squared_log_error as rmse

# %%
Pred = Dtr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_log_error as rmse

# %%
print(f" RMSE: {(rmse(y_test, Pred))*100:0.2f}%")
# Out:
#  RMSE: 41.79%

# %%
test_data = final_test_df.tail(28512)

# %%
pred = Dtr.predict(test_data)

# %%
df_submission = pd.read_csv("sample_submission.csv")

# %%
df_submission
# Out:
#             id  sales
# 0      3000888    0.0
# 1      3000889    0.0
# 2      3000890    0.0
# 3      3000891    0.0
# 4      3000892    0.0
# ...        ...    ...
# 28507  3029395    0.0
# 28508  3029396    0.0
# 28509  3029397    0.0
# 28510  3029398    0.0
# 28511  3029399    0.0
#
# [28512 rows x 2 columns]

# %%
df_submission['sales'] = pred

# %%
df_submission
# Out:
#             id     sales
# 0      3000888     2.000
# 1      3000889     0.000
# 2      3000890     1.000
# 3      3000891  2623.000
# 4      3000892     0.000
# ...        ...       ...
# 28507  3029395   297.789
# 28508  3029396   122.981
# 28509  3029397  1926.853
# 28510  3029398     5.000
# 28511  3029399    11.879
#
# [28512 rows x 2 columns]
